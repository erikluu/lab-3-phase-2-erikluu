# %% [markdown]
# <a href="https://colab.research.google.com/github/erikluu/lab-3-phase-2-erikluu/blob/main/Copy_of_DATA_301_Lab_3_Erik_Luu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Retrieval Practice and Learning
#
# What is the most effective way to learn a subject? Many students focus exclusively on the _encoding_ process---that is, how to get the knowledge into memory in the first place. For example, taking notes is an activity for encoding knowledge.
#
# _Retrieval_, on the other hand, is the process of reconstructing that knowledge from memory. [Karpicke and Blunt](http://science.sciencemag.org/content/331/6018/772) (2011) demonstrated that _retrieval_ is more effective for learning than activites designed to promote effective encoding. They conducted an experiment in which subjects had to learn about sea otters by reading a passage. Subjects were randomly assigned to one of two conditions: some were instructed to create a [concept map](https://en.wikipedia.org/wiki/Concept_map) as they read the passage, while others were instructed to practice retrieval (i.e., read the passage, recall as much as they could, read the text again, and recall again). The two main measurements they recorded were:
#
# 1. each subject's score on a follow-up learning test one week later
# 2. each subject's _prediction_ of how well they would do on that test
#
# In this lab, you will analyze data from a _replication_ of Karpicke and Blunt's experiment, conducted by Buttrick _et al_.
# - The data file is here: https://dlsun.github.io/pods/data/KarpickeBlunt2011Replication/data.csv.
# - The codebook (explaining what the variables mean) is here: https://dlsun.github.io/pods/data/KarpickeBlunt2011Replication/codebook.csv.

# %%
# READ IN THE DATA SET HERE
import pandas as pd
from altair import *

df_ret = pd.read_csv("https://dlsun.github.io/pods/data/KarpickeBlunt2011Replication/data.csv")
df_ret
# Out:
#       ID  Age  Gender   Date.P1  ... TS.avg Exc.1  Exc.2  Collection
# 0    KB1   18  Female  11/21/16  ...   0.39     0      0           1
# 1    KB2   18    Male  11/21/16  ...   0.42     0      0           1
# 2    KB3   18    Male  11/21/16  ...   0.08     0      0           1
# 3    KB4   19  Female  11/21/16  ...   0.43     0      0           1
# 4    KB5   19  Female  11/22/16  ...   0.27     0      0           1
# 5    KB6   19    Male  11/22/16  ...   0.43     0      0           1
# 6    KB7   18    Male  11/22/16  ...   0.37     0      0           1
# 7    KB8   20    Male  11/22/16  ...   0.45     0      0           1
# 8    KB9   20    Male  11/22/16  ...   0.61     0      0           1
# 9   KB10   20  Female  11/29/16  ...   0.68     0      0           1
# 10  KB11   21  Female  11/21/16  ...   0.34     0      0           1
# 11  KB12   18  Female  11/21/16  ...   0.79     0      0           1
# 12  KB13   20  Female  11/21/16  ...   0.80     0      0           1
# ...

# %% [markdown]
# # Question 1
#
# Which group felt like they learned more: the subjects who made concept maps or the ones who practiced retrieval? (Or are they about the same?) Make an appropriate visualization and explain what you see.
#
# _Hint:_ Use the variable `PR.2`, which contains the participants' predictions of how well they would do on a test one week later.

# %%
# YOUR CODE HERE
Chart(df_ret).mark_boxplot(extent='min-max').encode(
    x="PR.2",
    y="Condition"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# **YOUR EXPLANATION HERE**
#
# The overall spread and average of the predicitons of the retrieval group was much less that the concept group. A box plot is perfect for this comparison as we can see the spread, IQRs and median all in one place.

# %% [markdown]
# # Question 2
#
# Which group actually did better on the follow-up learning test one week later? Make an appropriate visualization and explain what you see.
#
# _Hint:_ Don't ask which variable you should use. That is for you to figure out. Read the codebook carefully (consulting the [original paper](http://science.sciencemag.org/content/331/6018/772), if necessary), make an informed decision, and explain your choice.

# %%
# YOUR CODE HERE

# TS.avg -> Test Score Averages for all participants
Chart(df_ret).mark_boxplot(extent='min-max').encode(
    x="TS.avg",
    y="Condition",
)
# Out:
# alt.Chart(...)

# %% [markdown]
# **YOUR EXPLANATION HERE**
#
# I chose TS.avg as it is the "Average of the first and second scorers' test scores." Since each participant took two tests, the average is the easiest way to display and interpret the scores. I chose to use a boxplot again as the IQRs are great ways of seeing how a group compares. As we can see, the retrieval group performed much better than the concept group and much better than predicted. It is the exact opposite for the concept group.

# %% [markdown]
# # Question 3
#
# How good were subjects at predicting how well they would do on the follow-up learning test? Calculate a measure of how well subjects predicted their performance and interpret the value in context. (Optionally, you may want to include a visualization as well.)

# %%
# YOUR CODE HERE
df_ret["PR.2 %"] = df_ret["PR.2"] * 100
df_ret["TS.avg %"] = df_ret["TS.avg"] * 100
df_ret["Percentage Difference"] = (df_ret["PR.2 %"] - df_ret["TS.avg %"]).abs()

df_PR_TS = pd.DataFrame()
df_PR_TS["Condition"] = df_ret["Condition"]
df_PR_TS["PR.2 %"] = df_ret["PR.2 %"]
df_PR_TS["TS.avg %"] = df_ret["TS.avg %"]
df_PR_TS["Percentage Difference"] = df_ret["Percentage Difference"]

s1 = df_PR_TS[df_PR_TS["Condition"] == "Concept"]
s2 = df_PR_TS[df_PR_TS["Condition"] == "Retrieval"]

pd.concat([d.reset_index(drop=True) for d in [s1, s2]], axis=1)

# Not working for some reason...
# Chart(df_ret).mark_circle().encode(
#     x="PR.2 %",
#     y="TS.avg %",
#     facet="Condition",
# )
# Out:
#    Condition  PR.2 % TS.avg %  ...  PR.2 % TS.avg %  Percentage Difference
# 0    Concept    80.0     39.0  ...    40.0     34.0                    6.0
# 1    Concept    70.0     42.0  ...    60.0     79.0                   19.0
# 2    Concept    70.0      8.0  ...    90.0     80.0                   10.0
# 3    Concept    70.0     43.0  ...    70.0     44.0                   26.0
# 4    Concept    95.0     27.0  ...    30.0     34.0                    4.0
# 5    Concept    60.0     43.0  ...    40.0     60.0                   20.0
# 6    Concept    60.0     37.0  ...    70.0     62.0                    8.0
# 7    Concept    50.0     45.0  ...    40.0     73.0                   33.0
# 8    Concept    60.0     61.0  ...    60.0     62.0                    2.0
# 9    Concept    90.0     68.0  ...    80.0     37.0                   43.0
# 10   Concept    80.0     58.0  ...    90.0    100.0                   10.0
# ...

# %%
cols = df_PR_TS["Condition"].map({
    "Concept": "orange",
    "Retrieval": "blue"
})

df_PR_TS.plot.scatter(x="TS.avg %", y="PR.2 %", 
                        c=cols, alpha=.5)
df_PR_TS["TS.avg %"].corr(df_PR_TS["PR.2 %"])
# Out:
# -0.04427748446680537

# %% [markdown]
# **YOUR EXPLANATION HERE**
#
# I concatted a simplified dataframe of showing off the absolute percent differences between the conditions. It looks like the concept's groups were more off than the retrieval group.
#
# The subjects were not very good at predicting how well they would do on the follow-up learning test. The calculated correlation being near zero shows that there is a very weak linear relationship between the prediction and the actual scores. Visually, we can see that very few predictions were accurate.

# %% [markdown]
# ## Submission Instructions
#
# - Copy this notebook to your own Drive, if you have not already.
# - Restart this notebook and run the cells from beginning to end.
#   - Go to Runtime > Restart and Run All.
# - Rename this notebook by clicking on "DATA 301 Lab 3 - YOUR NAMES HERE" at the very top of this page. Replace "YOUR NAMES HERE" with the first and last names of you (and your partner for Phase 2).
# - Get the link to your notebook:
#   - Click on "Share" at the top-right.
#   - Change the settings to "Anyone with the link can view".
#   - Copy the sharing link into Canvas.
